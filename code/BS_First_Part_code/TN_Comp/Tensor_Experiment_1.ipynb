# %%
import matplotlib.pyplot as plt
import logging
import src.mylib.pgm
from src.mylib.pgm import create_node
from src.mylib.pgm import create_node_from_pgm
from src.mylib.pgm import create_image_from_tensor
from src.mylib.pgm import crop_pgm_image

# %%
logging.basicConfig(level=logging.DEBUG, filename='Experiment1' + '.log', filemode='w', format="%(levelname)s - %(message)s")

pgmf_path = "gray8bit_Dataset/"
file_list = ['nightshot_iso_100.pgm', 
             'leaves_iso_1600.pgm', 
             'leaves_iso_200.pgm', 
             'zone_plate.pgm']

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file_name = next(enumerate(file_list))[1]
with open(pgmf_path + file_name, 'rb') as pgmf:
  im = plt.imread(pgmf)
  plt.imshow(im)
  plt.title('Original')
  plt.show()
  plt.imshow(crop_pgm_image(im))
  plt.title('Cropped')
  plt.show()
  im_node, _ = create_node_from_pgm(im, 8, transpose_modes=True)
  print(f"im_node.shape = {im_node.shape}")
  plt.imshow(create_image_from_tensor(im_node.tensor, transpose_modes=True))
  plt.title('Restored')
  plt.show()
# Out:
# im_node.shape = (8, 8, 8, 8, 8, 8)
